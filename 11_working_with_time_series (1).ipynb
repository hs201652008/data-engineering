# %%
"""
Native Python dates and times
"""
import pandas as pd
import numpy as np

# %%
# Parse a date from a string

# %%
# strftime()

# %%
"""
Types Arrays of Times: NumPy’s datetime64
"""

# %%
# Use datetime64()

# %%
# We can quickly do vectorized operations on datetime64

# %%
# Minite-based datetime

# %%
# Nanosecond-based datetime

t = np.datetime64('2022-10-18 11:39:10.20')    # default: ms

# %%
# datetime64 codes: Y, M, D, h...
t = np.datetime64('2022-10-18 11:39:10.20', 'Y')
print(t)

# %%
"""
Dates and Times in Pandas
"""

# %%
# Output the day of the week

# %%
# NumPy-style vectorized operations

date + pd.to_timedelta(np.arange(7))

# %%
"""
Pandas Time Seires: Indexing by Time
"""

# Creating a DatetimeIndex object
ind = pd.DatetimeIndex(['2022-10-27', '2022-10-28', '2022-10-29', '2022-10-30',
                        '2022-10-31', '2022-11-01', '2022-11-02'])

print(ind)

# %%
# Indexing by timestamps

# %%
# Indexing patterns

# %%
"""
Pandas Time Series Data Structures
"""

# Timestamp and DatetimeIndex

dates = pd.to_datetime([datetime(2015, 7, 3),
                      "4th of July, 2015",
                      '2015-Jul-6',
                      '07-07-2015',
                      '20150708'])

print(dates)

# %%
# DatetimeIndex -> PeriodIndex with to_period()

# %%
# TimedeltaIndex

# %%
"""
Regular Sequences
"""
# np : date + 4
# pd.date_range(). default freq: day
pd.date_range('2022-10-27', '2022-10-31')
# Out:
# DatetimeIndex(['2022-10-27', '2022-10-28', '2022-10-29', '2022-10-30',
#                '2022-10-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Use startpoint and num. of periods
pd.date_range('2022-10-27', periods=10)
# Out:
# DatetimeIndex(['2022-10-27', '2022-10-28', '2022-10-29', '2022-10-30',
#                '2022-10-31', '2022-11-01', '2022-11-02', '2022-11-03',
#                '2022-11-04', '2022-11-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Change the frequency
pd.date_range('2022-10-27', periods=12, freq='H')
# Out:
# DatetimeIndex(['2022-10-27 00:00:00', '2022-10-27 01:00:00',
#                '2022-10-27 02:00:00', '2022-10-27 03:00:00',
#                '2022-10-27 04:00:00', '2022-10-27 05:00:00',
#                '2022-10-27 06:00:00', '2022-10-27 07:00:00',
#                '2022-10-27 08:00:00', '2022-10-27 09:00:00',
#                '2022-10-27 10:00:00', '2022-10-27 11:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# pd.period_range()
pd.period_range('2022-10', periods=12, freq='M')
# Out:
# PeriodIndex(['2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03',
#              '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09'],
#             dtype='period[M]')

# %%
#timestamp vs period
period = pd.Period('2022-10-27')
timestamp = pd.Timestamp('2022-10-27')

print(period)
print(period.start_time)
print(period.end_time, '\n')

print(timestamp)
# Out:
# 2022-10-27
# 2022-10-27 00:00:00
# 2022-10-27 23:59:59.999999999
#
# 2022-10-27 00:00:00

# %%
# pd.timedelta_range()
pd.timedelta_range(0, periods=10, freq='H')
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00',
#                 '0 days 06:00:00', '0 days 07:00:00', '0 days 08:00:00',
#                 '0 days 09:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
# M: Month end

# %% [markdown]
# | Code   | Description         | Code   | Description          |
# |--------|---------------------|--------|----------------------|
# | ``D``  | Calendar day        | ``B``  | Business day         |
# | ``W``  | Weekly              |   -    |                      |
# | ``M``  | Month end           | ``BM`` | Business month end   |
# | ``Q``  | Quarter end         | ``BQ`` | Business quarter end |
# | ``A``  | Year end            | ``BA`` | Business year end    |
# | ``H``  | Hours               | ``BH`` | Business hours       |
# | ``T``  | Minutes             |   -    |                      |
# | ``S``  | Seconds             |   -    |                      |
# | ``L``  | Milliseonds         |   -    |                      |
# | ``U``  | Microseconds        |   -    |                      |
# | ``N``  | nanoseconds         |   -    |                      |

# %%
"""
Frequencies and Offsets
"""

# Frequency codes
pd.date_range('2022-11-01', periods=10, freq='H')
# Out:
# DatetimeIndex(['2022-11-01 00:00:00', '2022-11-01 01:00:00',
#                '2022-11-01 02:00:00', '2022-11-01 03:00:00',
#                '2022-11-01 04:00:00', '2022-11-01 05:00:00',
#                '2022-11-01 06:00:00', '2022-11-01 07:00:00',
#                '2022-11-01 08:00:00', '2022-11-01 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range('2022-11-01', periods=10, freq='M')
# Out:
# DatetimeIndex(['2022-11-30', '2022-12-31', '2023-01-31', '2023-02-28',
#                '2023-03-31', '2023-04-30', '2023-05-31', '2023-06-30',
#                '2023-07-31', '2023-08-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2022-11-01', periods=10, freq='BM')
# Out:
# DatetimeIndex(['2022-11-30', '2022-12-30', '2023-01-31', '2023-02-28',
#                '2023-03-31', '2023-04-28', '2023-05-31', '2023-06-30',
#                '2023-07-31', '2023-08-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
# Adding the suffix 'S': set into the beginning-based sequences
pd.date_range('2022-11-01', periods=10, freq='MS')
# Out:
# DatetimeIndex(['2022-11-01', '2022-12-01', '2023-01-01', '2023-02-01',
#                '2023-03-01', '2023-04-01', '2023-05-01', '2023-06-01',
#                '2023-07-01', '2023-08-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range('2022-11-01', periods=10, freq='BMS')
# Out:
# DatetimeIndex(['2022-11-01', '2022-12-01', '2023-01-02', '2023-02-01',
#                '2023-03-01', '2023-04-03', '2023-05-01', '2023-06-01',
#                '2023-07-03', '2023-08-01'],
#               dtype='datetime64[ns]', freq='BMS')

# %%
# Combining with numbers
pd.date_range('2022-11-01', periods=10, freq='2H30T')
# Out:
# DatetimeIndex(['2022-11-01 00:00:00', '2022-11-01 02:30:00',
#                '2022-11-01 05:00:00', '2022-11-01 07:30:00',
#                '2022-11-01 10:00:00', '2022-11-01 12:30:00',
#                '2022-11-01 15:00:00', '2022-11-01 17:30:00',
#                '2022-11-01 20:00:00', '2022-11-01 22:30:00'],
#               dtype='datetime64[ns]', freq='150T')

# %%
# Offsets
from pandas.tseries.offsets import DateOffset
ts = pd.Timestamp('2021-10-27 11:00:00')
ts + DateOffset(hours=40)
# Out:
# Timestamp('2021-10-29 03:00:00')

# %%
# Offsets(minus)
ts - DateOffset(years=71, months=4, days=5, hours=19, minutes=28, seconds=30)
# Out:
# Timestamp('1950-06-21 15:31:30')

# %%
"""
Time Series-specific Operations
"""
from pandas_datareader import data

# Get time series of stock prices from Yahoo Finance
goog = data.DataReader('GOOG', start='2004', end='2022',
                       data_source='yahoo')
goog.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2004-08-19  2.591785  2.390042  2.490664  2.499133  897427216.0   2.499133
# 2004-08-20  2.716817  2.503118  2.515820  2.697639  458857488.0   2.697639
# 2004-08-23  2.826406  2.716070  2.758411  2.724787  366857939.0   2.724787
# 2004-08-24  2.779581  2.579581  2.770615  2.611960  306396159.0   2.611960
# 2004-08-25  2.689918  2.587302  2.614201  2.640104  184645512.0   2.640104

# %%
# Use only closing prices
goog = goog['Close']
print(goog)
# Out:
# Date
# 2004-08-19      2.499133
# 2004-08-20      2.697639
# 2004-08-23      2.724787
# 2004-08-24      2.611960
# 2004-08-25      2.640104
#                  ...
# 2021-12-27    148.063995
# 2021-12-28    146.447998
# 2021-12-29    146.504501
# 2021-12-30    146.002502
# 2021-12-31    144.679504
# Name: Close, Length: 4374, dtype: float64

# %%
# Visualization setup
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot styles
# %config InlineBackend.figure_format = 'svg'

# %%
# Plotting
goog.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Resampling (down sampling)
goog.resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Resampling (up sampling)
goog.resample('H').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
"""
Time-shifts
"""

# shift() and tshift() by 900 days

fig, ax = plt.subplots(3, sharey=True, figsize=(12, 12))

# Apply a frequency to the data
goog = goog.asfreq('D', method='pad') # 'pad' = forward fill NaN values

# Plotting
goog.plot(ax=ax[0])
goog.shift(900).plot(ax=ax[1])
goog.tshift(900).plot(ax=ax[2])

# Legends and annotations
local_max = pd.to_datetime('2007-11-05')
offset = pd.Timedelta(900, 'D')

ax[0].legend(['input'], loc=2)
ax[0].get_xticklabels()[2].set(weight='heavy', color='red')
ax[0].axvline(local_max, alpha=0.3, color='red')

ax[1].legend(['shift(900)'], loc=2)
ax[1].get_xticklabels()[2].set(weight='heavy', color='red')
ax[1].axvline(local_max + offset, alpha=0.3, color='red')

ax[2].legend(['tshift(900)'], loc=2)
ax[2].get_xticklabels()[1].set(weight='heavy', color='red')
ax[2].axvline(local_max + offset, alpha=0.3, color='red');
# Out:
# C:\Users\minseok\AppData\Local\Temp/ipykernel_8608/2966154399.py:15: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   goog.tshift(900).plot(ax=ax[2])

# %%
# Print out the original series and shifted series
print(goog, '\n')
print(goog.shift(900), '\n')
print(goog.tshift(900))
# Out:
# Date
# 2004-08-19      2.499133
# 2004-08-20      2.697639
# 2004-08-21      2.697639
# 2004-08-22      2.697639
# 2004-08-23      2.724787
#                  ...
# 2021-12-27    148.063995
# 2021-12-28    146.447998
# 2021-12-29    146.504501
# 2021-12-30    146.002502
# 2021-12-31    144.679504
# Freq: D, Name: Close, Length: 6344, dtype: float64
#
# Date
# 2004-08-19          NaN
# 2004-08-20          NaN
# 2004-08-21          NaN
# 2004-08-22          NaN
# 2004-08-23          NaN
#                 ...
# 2021-12-27    57.210499
# 2021-12-28    57.244999
# 2021-12-29    57.244999
# 2021-12-30    57.244999
# 2021-12-31    57.516998
# Freq: D, Name: Close, Length: 6344, dtype: float64
#
# Date
# 2007-02-05      2.499133
# 2007-02-06      2.697639
# 2007-02-07      2.697639
# 2007-02-08      2.697639
# 2007-02-09      2.724787
#                  ...
# 2024-06-14    148.063995
# 2024-06-15    146.447998
# 2024-06-16    146.504501
# 2024-06-17    146.002502
# 2024-06-18    144.679504
# ...

# %%
"""
Rolling Windows
"""

rolling = goog.rolling(365, center=True)

data = pd.DataFrame({'input': goog,
                     'one-year rolling_mean': rolling.mean(), # moving average
                     'one-year rolling_std': rolling.std()})
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)

# %%
# Visualization of rolled data
goog.rolling(365).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>
